# %% [markdown]
# Customer Analysis Round 1
# Zsanett Borsos

# %%
import pandas as pd

# %%
file1 = pd.read_csv('C:/Users/zsbor/OneDrive/Desktop/Labs/CustomerAnalysisLab1/file1.csv')

# %%
file2 = pd.read_csv('C:/Users/zsbor/OneDrive/Desktop/Labs/CustomerAnalysisLab1/file2.csv')

# %%
file3 = pd.read_csv('C:/Users/zsbor/OneDrive/Desktop/Labs/CustomerAnalysisLab1/file3.csv')

# %% [markdown]
# Show the DataFrame's shape

# %%
file1
# Out:
#       Unnamed: 0 Customer          ST GENDER             Education  \
# 0              0  RB50392  Washington    NaN                Master
# 1              1  QZ44356     Arizona      F              Bachelor
# 2              2  AI49188      Nevada      F              Bachelor
# 3              3  WW63253  California      M              Bachelor
# 4              4  GA49547  Washington      M  High School or Below
# ...          ...      ...         ...    ...                   ...
# 4003        4003      NaN         NaN    NaN                   NaN
# 4004        4004      NaN         NaN    NaN                   NaN
# 4005        4005      NaN         NaN    NaN                   NaN
# 4006        4006      NaN         NaN    NaN                   NaN
# 4007        4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# ...

# %%
file2
# Out:
#      Unnamed: 0 Customer          ST GENDER Education Customer Lifetime Value  \
# 0             0  GS98873     Arizona      F  Bachelor              323912.47%
# 1             1  CW49887  California      F    Master              462680.11%
# 2             2  MY31220  California      F   College              899704.02%
# 3             3  UH35128      Oregon      F   College             2580706.30%
# 4             4  WH52799     Arizona      F   College              380812.21%
# ..          ...      ...         ...    ...       ...                     ...
# 991         991  HV85198     Arizona      M    Master              847141.75%
# 992         992  BS91566     Arizona      F   College              543121.91%
# 993         993  IL40123      Nevada      F   College              568964.41%
# 994         994  MY32149  California      F    Master              368672.38%
# 995         995  SA91515  California      M  Bachelor              399258.39%
#
# ...

# %%
file3
# Out:
#       Unnamed: 0 Customer       State  Customer Lifetime Value  \
# 0              0  SA25987  Washington              3479.137523
# 1              1  TB86706     Arizona              2502.637401
# 2              2  ZL73902      Nevada              3265.156348
# 3              3  KX23516  California              4455.843406
# 4              4  FN77294  California              7704.958480
# ...          ...      ...         ...                      ...
# 7065        7065  LA72316  California             23405.987980
# 7066        7066  PK87824  California              3096.511217
# 7067        7067  TD14365  California              8163.890428
# 7068        7068  UP19263  California              7524.442436
# 7069        7069  Y167826  California              2611.836866
#
#                  Education Gender  Income  Monthly Premium Auto  \
# 0     High School or Below      M       0                   104
# 1                   Master      M       0                    66
# ...

# %%
file1.shape
# Out:
# (4008, 12)

# %%
file2.shape
# Out:
# (996, 12)

# %%
file3.shape
# Out:
# (7070, 12)

# %%
file1.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'ST', 'GENDER', 'Education',
#        'Customer Lifetime Value', 'Income', 'Monthly Premium Auto',
#        'Number of Open Complaints', 'Policy Type', 'Vehicle Class',
#        'Total Claim Amount'],
#       dtype='object')

# %%
file1 = file1.rename({'Unnamed: 0':'unnamed', 'Customer':'customer', 'ST':'state', 'GENDER':'gender', 'Education':'education', 'Customer Lifetime Value':'customer_lifetime_value', 'Income':'income', 'Monthly Premium Auto':'monthly_premium_auto', 'Number of Open Complaints':'number_of_open_complaints', 'Policy Type':'policy_type', 'Vehicle Class':'vehicle_class', 'Total Claim Amount':'total_claim_amount'}, axis='columns')

# %%
file1.columns
# Out:
# Index(['unnamed', 'customer', 'state', 'gender', 'education',
#        'customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'number_of_open_complaints', 'policy_type', 'vehicle_class',
#        'total_claim_amount'],
#       dtype='object')

# %%
file1
# Out:
#       unnamed customer       state gender             education  \
# 0           0  RB50392  Washington    NaN                Master
# 1           1  QZ44356     Arizona      F              Bachelor
# 2           2  AI49188      Nevada      F              Bachelor
# 3           3  WW63253  California      M              Bachelor
# 4           4  GA49547  Washington      M  High School or Below
# ...       ...      ...         ...    ...                   ...
# 4003     4003      NaN         NaN    NaN                   NaN
# 4004     4004      NaN         NaN    NaN                   NaN
# 4005     4005      NaN         NaN    NaN                   NaN
# 4006     4006      NaN         NaN    NaN                   NaN
# 4007     4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# ...

# %%
file2.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'ST', 'GENDER', 'Education',
#        'Customer Lifetime Value', 'Income', 'Monthly Premium Auto',
#        'Number of Open Complaints', 'Total Claim Amount', 'Policy Type',
#        'Vehicle Class'],
#       dtype='object')

# %%
file2 = file2.rename({'Unnamed: 0':'unnamed', 'Customer':'customer', 'ST':'state', 'GENDER':'gender', 'Education':'education', 'Customer Lifetime Value':'customer_lifetime_value', 'Income':'income', 'Monthly Premium Auto':'monthly_premium_auto', 'Number of Open Complaints':'number_of_open_complaints', 'Total Claim Amount':'total_claim_amount', 'Policy Type':'policy_type', 'Vehicle Class':'vehicle_class'}, axis='columns')

# %%
file2
# Out:
#      unnamed customer       state gender education customer_lifetime_value  \
# 0          0  GS98873     Arizona      F  Bachelor              323912.47%
# 1          1  CW49887  California      F    Master              462680.11%
# 2          2  MY31220  California      F   College              899704.02%
# 3          3  UH35128      Oregon      F   College             2580706.30%
# 4          4  WH52799     Arizona      F   College              380812.21%
# ..       ...      ...         ...    ...       ...                     ...
# 991      991  HV85198     Arizona      M    Master              847141.75%
# 992      992  BS91566     Arizona      F   College              543121.91%
# 993      993  IL40123      Nevada      F   College              568964.41%
# 994      994  MY32149  California      F    Master              368672.38%
# 995      995  SA91515  California      M  Bachelor              399258.39%
#
#      income  monthly_premium_auto number_of_open_complaints  \
# ...

# %%
file3.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Education', 'Gender', 'Income', 'Monthly Premium Auto',
#        'Number of Open Complaints', 'Policy Type', 'Total Claim Amount',
#        'Vehicle Class'],
#       dtype='object')

# %%
file3 = file3.rename({'Unnamed: 0':'unnamed', 'Customer':'customer', 'State':'state', 'Customer Lifetime Value':'customer_lifetime_value', 'Education':'education', 'Gender':'gender', 'Income':'income', 'Monthly Premium Auto':'monthly_premium_auto', 'Number of Open Complaints':'number_of_open_complaints', 'Total Claim Amount':'total_claim_amount', 'Policy Type':'policy_type', 'Vehicle Class':'vehicle_class'}, axis='columns')

# %%
file3
# Out:
#       unnamed customer       state  customer_lifetime_value  \
# 0           0  SA25987  Washington              3479.137523
# 1           1  TB86706     Arizona              2502.637401
# 2           2  ZL73902      Nevada              3265.156348
# 3           3  KX23516  California              4455.843406
# 4           4  FN77294  California              7704.958480
# ...       ...      ...         ...                      ...
# 7065     7065  LA72316  California             23405.987980
# 7066     7066  PK87824  California              3096.511217
# 7067     7067  TD14365  California              8163.890428
# 7068     7068  UP19263  California              7524.442436
# 7069     7069  Y167826  California              2611.836866
#
#                  education gender  income  monthly_premium_auto  \
# 0     High School or Below      M       0                   104
# 1                   Master      M       0                    66
# ...

# %%
file1.columns
# Out:
# Index(['unnamed', 'customer', 'state', 'gender', 'education',
#        'customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'number_of_open_complaints', 'policy_type', 'vehicle_class',
#        'total_claim_amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['unnamed', 'customer', 'state', 'gender', 'education',
#        'customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'number_of_open_complaints', 'total_claim_amount', 'policy_type',
#        'vehicle_class'],
#       dtype='object')

# %%
file2 = file2[['unnamed', 'customer', 'state', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']]

# %%
file2
# Out:
#      unnamed customer       state gender education customer_lifetime_value  \
# 0          0  GS98873     Arizona      F  Bachelor              323912.47%
# 1          1  CW49887  California      F    Master              462680.11%
# 2          2  MY31220  California      F   College              899704.02%
# 3          3  UH35128      Oregon      F   College             2580706.30%
# 4          4  WH52799     Arizona      F   College              380812.21%
# ..       ...      ...         ...    ...       ...                     ...
# 991      991  HV85198     Arizona      M    Master              847141.75%
# 992      992  BS91566     Arizona      F   College              543121.91%
# 993      993  IL40123      Nevada      F   College              568964.41%
# 994      994  MY32149  California      F    Master              368672.38%
# 995      995  SA91515  California      M  Bachelor              399258.39%
#
# ...

# %%
file3.columns
# Out:
# Index(['unnamed', 'customer', 'state', 'customer_lifetime_value', 'education',
#        'gender', 'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
file3 = file3[['unnamed', 'customer', 'state', 'gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']]

# %%
file3
# Out:
#       unnamed customer       state gender             education  \
# 0           0  SA25987  Washington      M  High School or Below
# 1           1  TB86706     Arizona      M                Master
# 2           2  ZL73902      Nevada      F              Bachelor
# 3           3  KX23516  California      F  High School or Below
# 4           4  FN77294  California      M  High School or Below
# ...       ...      ...         ...    ...                   ...
# 7065     7065  LA72316  California      M              Bachelor
# 7066     7066  PK87824  California      F               College
# 7067     7067  TD14365  California      M              Bachelor
# 7068     7068  UP19263  California      M               College
# 7069     7069  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# ...

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   unnamed                    4008 non-null   int64
#  1   customer                   1071 non-null   object
#  2   state                      1071 non-null   object
#  3   gender                     954 non-null    object
#  4   education                  1071 non-null   object
#  5   customer_lifetime_value    1068 non-null   object
#  6   income                     1071 non-null   float64
#  7   monthly_premium_auto       1071 non-null   float64
#  8   number_of_open_complaints  1071 non-null   object
#  9   policy_type                1071 non-null   object
#  10  vehicle_class              1071 non-null   object
#  11  total_claim_amount         1071 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 375.9+ KB

# %%
display(file1.loc[1070:1071])
# Out:
#       unnamed customer       state gender education customer_lifetime_value  \
# 1070     1070  MY31220  California      F   College              899704.02%
# 1071     1071      NaN         NaN    NaN       NaN                     NaN
#
#        income  monthly_premium_auto number_of_open_complaints    policy_type  \
# 1070  54230.0                 112.0                    1/0/00  Personal Auto
# 1071      NaN                   NaN                       NaN            NaN
#
#      vehicle_class  total_claim_amount
# 1070  Two-Door Car               537.6
# 1071           NaN                 NaN

# %%
file1 = file1.drop(file1.index[1071:4008])

# %%
file1
# Out:
#       unnamed customer       state gender             education  \
# 0           0  RB50392  Washington    NaN                Master
# 1           1  QZ44356     Arizona      F              Bachelor
# 2           2  AI49188      Nevada      F              Bachelor
# 3           3  WW63253  California      M              Bachelor
# 4           4  GA49547  Washington      M  High School or Below
# ...       ...      ...         ...    ...                   ...
# 1066     1066  TM65736      Oregon      M                Master
# 1067     1067  VJ51327        Cali      F  High School or Below
# 1068     1068  GS98873     Arizona      F              Bachelor
# 1069     1069  CW49887  California      F                Master
# 1070     1070  MY31220  California      F               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# ...

# %%
masterfile = pd.concat([file1,file2,file3], axis=0)

# %%
masterfile
# Out:
#       unnamed customer       state gender             education  \
# 0           0  RB50392  Washington    NaN                Master
# 1           1  QZ44356     Arizona      F              Bachelor
# 2           2  AI49188      Nevada      F              Bachelor
# 3           3  WW63253  California      M              Bachelor
# 4           4  GA49547  Washington      M  High School or Below
# ...       ...      ...         ...    ...                   ...
# 7065     7065  LA72316  California      M              Bachelor
# 7066     7066  PK87824  California      F               College
# 7067     7067  TD14365  California      M              Bachelor
# 7068     7068  UP19263  California      M               College
# 7069     7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# ...

# %%
masterfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9137 entries, 0 to 7069
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   unnamed                    9137 non-null   int64
#  1   customer                   9137 non-null   object
#  2   state                      9137 non-null   object
#  3   gender                     9015 non-null   object
#  4   education                  9137 non-null   object
#  5   customer_lifetime_value    9130 non-null   object
#  6   income                     9137 non-null   float64
#  7   monthly_premium_auto       9137 non-null   float64
#  8   number_of_open_complaints  9137 non-null   object
#  9   policy_type                9137 non-null   object
#  10  vehicle_class              9137 non-null   object
#  11  total_claim_amount         9137 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 928.0+ KB

# %%
masterfile = masterfile.drop(masterfile.columns[[4, 8]], axis = 1)

# %%
masterfile
# Out:
#       unnamed customer       state gender customer_lifetime_value   income  \
# 0           0  RB50392  Washington    NaN                     NaN      0.0
# 1           1  QZ44356     Arizona      F              697953.59%      0.0
# 2           2  AI49188      Nevada      F             1288743.17%  48767.0
# 3           3  WW63253  California      M              764586.18%      0.0
# 4           4  GA49547  Washington      M              536307.65%  36357.0
# ...       ...      ...         ...    ...                     ...      ...
# 7065     7065  LA72316  California      M             23405.98798  71941.0
# 7066     7066  PK87824  California      F             3096.511217  21604.0
# 7067     7067  TD14365  California      M             8163.890428      0.0
# 7068     7068  UP19263  California      M             7524.442436  21941.0
# 7069     7069  Y167826  California      M             2611.836866      0.0
#
# ...

# %%
masterfile['customer_lifetime_value'] = masterfile['customer_lifetime_value'].str.replace('%', '')

# %%
masterfile
# Out:
#       unnamed customer       state gender customer_lifetime_value   income  \
# 0           0  RB50392  Washington    NaN                     NaN      0.0
# 1           1  QZ44356     Arizona      F               697953.59      0.0
# 2           2  AI49188      Nevada      F              1288743.17  48767.0
# 3           3  WW63253  California      M               764586.18      0.0
# 4           4  GA49547  Washington      M               536307.65  36357.0
# ...       ...      ...         ...    ...                     ...      ...
# 7065     7065  LA72316  California      M                     NaN  71941.0
# 7066     7066  PK87824  California      F                     NaN  21604.0
# 7067     7067  TD14365  California      M                     NaN      0.0
# 7068     7068  UP19263  California      M                     NaN  21941.0
# 7069     7069  Y167826  California      M                     NaN      0.0
#
# ...

# %%
masterfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9137 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   unnamed                  9137 non-null   int64
#  1   customer                 9137 non-null   object
#  2   state                    9137 non-null   object
#  3   gender                   9015 non-null   object
#  4   customer_lifetime_value  2060 non-null   object
#  5   income                   9137 non-null   float64
#  6   monthly_premium_auto     9137 non-null   float64
#  7   policy_type              9137 non-null   object
#  8   vehicle_class            9137 non-null   object
#  9   total_claim_amount       9137 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 785.2+ KB

# %%
masterfile['customer_lifetime_value'] = masterfile['customer_lifetime_value'].apply(float)

# %%
masterfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9137 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   unnamed                  9137 non-null   int64
#  1   customer                 9137 non-null   object
#  2   state                    9137 non-null   object
#  3   gender                   9015 non-null   object
#  4   customer_lifetime_value  2060 non-null   float64
#  5   income                   9137 non-null   float64
#  6   monthly_premium_auto     9137 non-null   float64
#  7   policy_type              9137 non-null   object
#  8   vehicle_class            9137 non-null   object
#  9   total_claim_amount       9137 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 785.2+ KB

# %%
masterfile['customer_lifetime_value'] = masterfile['customer_lifetime_value'] * 100

# %%
masterfile
# Out:
#       unnamed customer       state gender  customer_lifetime_value   income  \
# 0           0  RB50392  Washington    NaN                      NaN      0.0
# 1           1  QZ44356     Arizona      F               69795359.0      0.0
# 2           2  AI49188      Nevada      F              128874317.0  48767.0
# 3           3  WW63253  California      M               76458618.0      0.0
# 4           4  GA49547  Washington      M               53630765.0  36357.0
# ...       ...      ...         ...    ...                      ...      ...
# 7065     7065  LA72316  California      M                      NaN  71941.0
# 7066     7066  PK87824  California      F                      NaN  21604.0
# 7067     7067  TD14365  California      M                      NaN      0.0
# 7068     7068  UP19263  California      M                      NaN  21941.0
# 7069     7069  Y167826  California      M                      NaN      0.0
#
# ...

# %%
print(masterfile.duplicated().sum())
# Out:
# 0

# %%
customers_filter = masterfile[(masterfile.income < 0)]

# %%
customers_filter
# Out:
# Empty DataFrame
# Columns: [unnamed, customer, state, gender, customer_lifetime_value, income, monthly_premium_auto, policy_type, vehicle_class, total_claim_amount]
# Index: []
